# %% [markdown]
# # A Cappella Transcription: Vocal Separation on Vertex AI
#
# This notebook provides an NVIDIA GPU environment to run the `Phase 2` vocal separation pipeline, bypassing the Apple Silicon memory limitations.
#
# **Instructions:**
# 1. Upload the entire `A-Cappella-Transcription` directory to this Vertex AI instance.
# 2. Run the cells below to install dependencies and execute the separator.
# 3. The separated SATB stems will appear in `data/output/separation/SepACap`!

# %%
# !sudo apt-get update && sudo apt-get install -y ffmpeg
# !pip install -r requirements.txt
# !pip install loguru torchmetrics einops torchaudio huggingface_hub pyyaml

# %%
import os

# Ensure we are in the root directory
if not os.path.exists('scripts/run_phase2.py'):
    if os.path.exists('A-Cappella-Transcription/scripts/run_phase2.py'):
        # %cd A-Cappella-Transcription
    else:
        print("Please ensure the A-Cappella-Transcription directory is uploaded to this instance!")

# %%
# !PYTHONPATH=. python scripts/run_phase2.py
